# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in ./.conda/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: pandas in ./.conda/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in ./.conda/lib/python3.10/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.10/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in ./.conda/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.10/site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: numpy>=1.20 in ./.conda/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in ./.conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: joblib>=1.1.1 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: seaborn in ./.conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./.conda/lib/python3.10/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./.conda/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in ./.conda/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('mosquito_indicator.csv')
df.head()
# Out:
#          date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)
# 0  2016-05-01               254.4       0.0       18.8      12.2      26.0
# 1  2016-05-02               273.5      16.5       21.1      16.5      28.4
# 2  2016-05-03               304.0      27.0       12.9       8.9      17.6
# 3  2016-05-04               256.2       0.0       15.7      10.2      20.6
# 4  2016-05-05               243.8       7.5       18.9      10.2      26.9

# %%
df.describe()
# Out:
#        mosquito_Indicator     rain(mm)    mean_T(℃)     min_T(℃)     max_T(℃)
# count         1342.000000  1342.000000  1342.000000  1342.000000  1342.000000
# mean           251.991803     3.539866    14.166021    10.005663    19.096870
# std            295.871336    13.868106    10.943990    11.109489    11.063394
# min              0.000000     0.000000   -14.800000   -17.800000   -10.700000
# 25%              5.500000     0.000000     4.500000     0.300000     9.300000
# 50%             91.900000     0.000000    16.500000    11.500000    21.900000
# 75%            480.400000     0.400000    23.300000    19.500000    28.175000
# max           1000.000000   144.500000    33.700000    30.300000    39.600000

# %%
import seaborn as sns

sns.pairplot(df.sample(frac=0.3))

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

X = df.values[:, 2:]
y = df.values[:, 1]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

model_ols = linear_model.LinearRegression()
model_ols.fit(X_train, y_train)
mean_absolute_error(y_test, model_ols.predict(X_test))
# Out:
# 154.43967250856923

# %%
model_ols.predict(np.array([20, 30, 24, 36]).reshape(1, -1))
# Out:
# array([533.31189491])

# %%
import pickle

pickle.dump(model_ols, open('model.pkl', 'wb'))
model_ols = pickle.load(open('model.pkl', 'rb'))
mean_absolute_error(y_test, model_ols.predict(X_test))
# Out:
# 154.43967250856923

# %%
model_ols.predict(np.array([20, 30, 24, 36]).reshape(1, -1))
# Out:
# array([533.31189491])
